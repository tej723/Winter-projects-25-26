# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTIONS 1 : Preps

# %% [markdown]
# ### Flat Image : reference as "flat"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Edge Image : reference as "edge"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Corner Image : reference as "corner"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c1 = """
...

"""

img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Multiple Coorners : reference as "corner2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c2 = """
...

"""

img_data_c2 = base64.b64decode(base64_image_c2)
corner2 = np.array(Image.open(io.BytesIO(img_data_c2)))

plt.imshow(corner2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(1121.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 1 : reference as "ball"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(625.5), np.float64(416.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 2 : reference as "ball2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball2 = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(642.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# ## SECTION 2 : Questions

# %% [markdown]
# ### Part A - Corner Detection
#
# Pick images of your choice which you feel should give a good output. Use above ones if you cannot find any else.
# Create or pick 3 images : one flat, one edge, one corner image. Examples shown above, you are free to you them too.
# Use the sobel kernels to find Ix and Iy ( or Gx and Gy whatever you call it ) and plot them. Then, create a scatter plot for Iy vs Ix. If you threshold, mention clearly that you have along with the threshold value too. Ideally make a function that takes the image and prints the graphs, also make the function return the Iy and Ix values for further questions.
# Hint: use grayscale only.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.
import cv2

# %%
# Finding Ix and Iy using sobel kernels
def Grad(img_gray,T):
  Ix=cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
  Iy=cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
  mag=np.sqrt(Ix**2+Iy**2)
  threshold_region=(mag>T)
  Ix=Ix[threshold_region]
  Iy=Iy[threshold_region]
  return Ix,Iy

# Flat
flat_gray=cv2.cvtColor(flat,cv2.COLOR_BGR2GRAY)
Ix_flat,Iy_flat=Grad(flat_gray,10)
Ix_flat_=Ix_flat.ravel()
Iy_flat_=Iy_flat.ravel()

# Edge
edge_gray=cv2.cvtColor(edge,cv2.COLOR_BGR2GRAY)
Ix_edge,Iy_edge=Grad(edge_gray,10)
Ix_edge_=Ix_edge.ravel()
Iy_edge_=Iy_edge.ravel()

# Corner
corner_gray=cv2.cvtColor(corner,cv2.COLOR_BGR2GRAY)
Ix_corner,Iy_corner=Grad(corner_gray,10)
Ix_corner_=Ix_corner.ravel()
Iy_corner_=Iy_corner.ravel()

plt.figure(figsize=(24,6))

# Flat region
plt.subplot(1,6,1)
plt.imshow(flat_gray,cmap='gray')
plt.axis("off")
plt.title("Flat Image")

plt.subplot(1, 6, 2)
plt.scatter(Ix_flat_, Iy_flat_, s=3, alpha=0.3)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title("Flat Region")
plt.xlabel("Ix")
plt.ylabel("Iy")
plt.grid(True)


# Edge region
plt.subplot(1,6,3)
plt.imshow(edge_gray,cmap='gray')
plt.axis("off")
plt.title("Edge Image")

plt.subplot(1, 6, 4)
plt.scatter(Ix_edge_, Iy_edge_, s=3, alpha=0.3)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title("Edge Region")
plt.xlabel("Ix")
plt.ylabel("Iy")
plt.grid(True)



# Corner region
plt.subplot(1,6,5)
plt.imshow(corner_gray,cmap='gray')
plt.axis("off")
plt.title("Corner Image")

plt.subplot(1, 6, 6)
plt.scatter(Ix_corner_, Iy_corner_, s=3, alpha=0.3)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title("Corner Region")
plt.xlabel("Ix")
plt.ylabel("Iy")
plt.grid(True)


plt.show()

# %% [markdown]
# ### Part B - Ellipse Fitting and R Maps for Corner Detection
#
# Now, use the above functions ( basically Ix and Iy ) and the formulas in the pre-session videos to find values of a,b and c ( the second moments ) and calculate the eigenvalues lambda1 and lambda2. Then use those to create an R map for the entire image. Display the R map. Do it for the 3 images of part A. So, you might want to create a function that takes the image, loops over the pixels with a window, fits the ellipse over the window, calculates the lambdas, and value of R, essentially finding R values for all the pixels and returning an R-map ( a 2d image with only one channel where the value of a pixel is the r-value of that pixel in the original grayscale image ). Now, display these R maps. Notice how the corners are clearly visible in white.

# %%
def Ellipse(Ix, Iy):
    # Find a,b,c using 2nd moments
    a = np.sum(Ix**2)
    b = 2*np.sum(Ix * Iy)
    c = np.sum(Iy**2)

    # Calculate lambda1 and lambda2
    lambda1 = (a + c - np.sqrt((a - c)**2 + b**2)) / 2
    lambda2 = (a + c + np.sqrt((a - c)**2 + b**2)) / 2
    return lambda1, lambda2

def R(img_gray,k, T):

  # Obtaining Gradients
  Ix=cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
  Iy=cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
  h, w = Ix.shape
  R = np.zeros((h, w))

  for i in range(1, h-1):
    for j in range(1, w-1):

      Ix_w = Ix[i-1:i+2, j-1:j+2].ravel()
      Iy_w = Iy[i-1:i+2, j-1:j+2].ravel()

      lambda1, lambda2 = Ellipse(Ix_w, Iy_w)

      # Obtaining R value
      R[i, j] = lambda1*lambda2-k*(lambda1+lambda2)**2


  return (R > T).astype(np.uint8)*255


R_flat=R(flat_gray,0.04,0)
R_edge=R(edge_gray,0.04,0)
R_corner=R(corner_gray,0.04,0)

# Displaying images
plt.figure(figsize=(24,6))
# Flat
plt.subplot(1,6,1)
plt.imshow(flat_gray,cmap='gray')
plt.axis("off")
plt.title("Flat Image")

plt.subplot(1, 6, 2)
plt.imshow(R_flat,cmap='gray')
plt.axis("off")
plt.title("Flat R Map")


# Edge
plt.subplot(1,6,3)
plt.imshow(edge_gray,cmap='gray')
plt.axis("off")
plt.title("Edge Image")

plt.subplot(1, 6, 4)
plt.imshow(R_edge,cmap='gray')
plt.axis("off")
plt.title("Edge R Map")


# Corner
plt.subplot(1,6,5)
plt.imshow(corner_gray,cmap='gray')
plt.axis("off")
plt.title("Corner Image")

plt.subplot(1, 6, 6)
plt.imshow(R_corner,cmap='gray')
plt.axis("off")
plt.title("Corner R Map")

plt.show()

# %% [markdown]
# * Explaining Observations:
#  For flat and edge: Ix and Iy are roughly zero
#  For corner there is a small region, where Ix and Iy crosses threshold(very small region), hence we get a bright point

# %% [markdown]
# ### Part C - Hough Transforms
#
# Again, import an image, create a function that takes the image, finds the canny edge map, then loops through it to find the equivalent line of each pixel, checks whether the slope and intercept are within acceptable limits of the accumulator size ( if not, discard ), does the voting procedure and creates the accumulator. Now, choose an accurate threshold for the accumulator to get the slope and intercept for a good number of lines in the image. One thing you can do is normalise the accumulator and use a 90 percent threshold ( just an example, im not telling if 90p is a good one or not ), then, mark the lines in the image using cv2 and display the final output. For the slope and intercept, choose the limit as per your image to get a good output. Please dont make it super large so it take hours to run and give the output.
#
# Now, you can do the same but with rho theta method. Do this in a separate code cell from slope-intercept method and notice how fast this is

# %%
img=cv2.imread('road.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Original')
plt.axis("off")
plt.subplot(1,2,2)
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray,cmap='gray')
plt.title('Grayscale')
plt.axis("off")
plt.show()

# %%
def draw_lines_m_c(img_gray, T):
    h, w = img_gray.shape

    #  Canny edge detection
    edges = cv2.Canny(img_gray, 100, 200)

    #  Extract edge pixel coordinates(Binary Image)
    ys, xs = np.where(edges > 0)

    #  Define slope (m) and intercept (c) ranges
    m_values = np.linspace(-5, 5, 1500)
    c_values= np.linspace(-h, h,1500 )
    Nm = len(m_values)
    Nc = len(c_values)

    #  Accumulator
    acc = np.zeros((len(m_values), len(c_values)), dtype=np.float32)

    d = c_values[1] - c_values[0]

    #  Voting
    for x, y in zip(xs, ys):
        for mi, m in enumerate(m_values):
            c = y - m * x
            ci = int((c - c_values[0]) // d)
            if 0 <= ci < len(c_values):
                acc[mi, ci] += 1

    #  Normalize accumulator
    if acc.max() > 0:
        acc /= acc.max()

    #  Threshold accumulator
    indices = np.where(acc > T)

    detected_m = m_values[indices[0]]
    detected_c = c_values[indices[1]]

    # Drawing Lines
    for m, c in zip(detected_m, detected_c):
        x1, x2 = 0, w
        y1 = int(m * x1 + c)
        y2 = int(m * x2 + c)

        if 0 <= y1 < h and 0 <= y2 < h:
            cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 1)

    #  Display results
    plt.figure(figsize=(15,5))

    plt.subplot(1,3,1)
    plt.title("Edge Map")
    plt.imshow(edges, cmap='gray')
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.title("Accumulator")
    plt.imshow(acc, cmap='gray',)
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.title("C-M paramaterization")
    plt.imshow(img)
    plt.axis("off")

    plt.show()
draw_lines_m_c(img_gray,0.9)

# %%
# Rho-Theta Parameter Space
def draw_lines_r_theta(img_gray, T):
    h, w = img_gray.shape

    # 1. Canny edge detection
    edges = cv2.Canny(img_gray, 100, 200)

    # 2 Extract edge pixel coordinates(Binary Image)
    ys,xs=np.where(edges>0)

    #3 rho, theta
    r=np.sqrt(h**2+w**2)
    rho_values=np.linspace(0,r,num=500)
    theta_values=np.linspace(0,np.pi,num=900)
    Nr=len(rho_values)
    Nt=len(theta_values)

    #4. Accumulator
    acc=np.zeros((Nr,Nt),dtype=np.float32)

    d=rho_values[1]-rho_values[0]


    #5. Voting
    for x,y in zip(xs,ys):
      for theta_i, theta in enumerate(theta_values):
        rho=-x*np.sin(theta)+y*np.cos(theta)
        rho_i=int((rho-rho_values[0])//d)
        if 0<=rho_i<Nr:
          acc[rho_i,theta_i]+=1

    #6. Normalize
    if acc.max()>0:
      acc/=acc.max()

    #7. Threshold
    indices=np.where(acc>T)

    detected_rho=rho_values[indices[0]]
    detected_theta=theta_values[indices[1]]

    for rho,theta in zip(detected_rho,detected_theta):
      a=np.cos(theta)
      b=np.sin(theta)
      x0=a*rho
      y0=b*rho
      x1=int(x0-1000*(b))
      y1=int(y0+1000*(a))
      x2=int(x0+1000*(b))
      y2=int(y0-1000*(a))
      if 0 <= y1 < h and 0 <= y2 < h:
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),1)

    plt.figure(figsize=(15,5))
    #  Edge-Map
    plt.subplot(1,3,1)
    plt.title("Edge Map")
    plt.imshow(edges, cmap='gray')
    plt.axis("off")

    # Accumulator
    plt.subplot(1,3,2)
    plt.title("Accumulator")
    plt.imshow(acc, cmap='gray',)
    plt.axis("off")

    # Hough Lines
    plt.subplot(1,3,3)
    plt.title("Rho-Theta Parametrization")
    plt.imshow(img)
    plt.axis("off")

    plt.show()

draw_lines_r_theta(img_gray,0.9)

# %% [markdown]
# ### Bonus - Part D
#
# Here, what you have to do is something like :
# 1. Create a python function that will take the first image and a set of coordinates ( x1,y1 ) - top left and ( x2,y2 ) - bottom right to form a box around the white ball. Now, find gradients, select the biggest completed gradient ( maximum area contour ) and then create an RGBA ( 4 channel ) stencil.
#
# 2. Now, create another function that takes this stencil and second image and a coordinate ( x3,y3 ). Now, treat ( x3,y3 ) as center point and overlap the RGBA stencil with second image. Keep x3 y3 such that it is towards the right to make it look like that white ball is on the green pool image.
#
#
# Again, I do not expect you guys to get a really good result. Try your best though.

# %%
ball
# Out:
# array([[[ 91,  71,  46],
#         [ 91,  71,  46],
#         [ 92,  72,  47],
#         ...,
#         [ 87,  71,  58],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 90,  70,  47],
#         [ 90,  70,  47],
#         [ 90,  70,  47],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 87,  66,  45],
#         [ 87,  66,  45],
#         [ 87,  66,  45],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        ...,
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  7,  84, 215],
#         [  7,  84, 215],
#         [  7,  84, 215],
#         ...,
#         [  7,  70, 198],
#         [  7,  70, 198],
#         [  7,  70, 198]]], dtype=uint8)

# %%
def create_ball_stencil(img, x1, y1, x2, y2):
    crop = img[y1:y2, x1:x2].copy()

    gray = cv2.cvtColor(crop, cv2.COLOR_RGB2GRAY)

    # Gradient
    Ix = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    Iy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    mag = np.sqrt(Ix**2 + Iy**2)

    # Threshold gradient magnitude, better way to threshold to obtain a good output
    threshold = np.mean(mag)
    binary = (mag > threshold).astype(np.uint8) * 255

    # Find contours
    contours, _ = cv2.findContours(
        binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )


    # Maximum Area
    largest_area = max(contours, key=cv2.contourArea)


    # Create a mask and drawing contours
    mask = np.zeros(gray.shape, dtype=np.uint8)
    cv2.drawContours(mask, [largest_area], -1, 255, -1)
    # Took Help from OpenCV documentation and AI

    alpha = mask / 255.0
    rgba = np.zeros((crop.shape[0], crop.shape[1], 4), dtype=float)
    rgba[..., :3] = crop / 255.0
    rgba[..., 3] = alpha

    return rgba


ball_stencil = create_ball_stencil(ball, 90,160,250,320) # Trying different values to get the result

# Display Image
plt.figure(figsize=(4,4))
plt.imshow(ball_stencil[..., :3])
plt.title("Stencil")
plt.axis("off")
plt.show()

# %%
ball2
# Out:
# array([[[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        ...,
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]]], dtype=uint8)

# %%
def overlay_stencil(ball, stencil, cx, cy):
    #Nomralize
    ball = ball.astype(float) / 255.0
    out = ball.copy()

    h, w = stencil.shape[:2]
    # Center
    x0 = cx - w // 2
    y0 = cy - h // 2

    for i in range(h):
        for j in range(w):
            y = y0 + i
            x = x0 + j
            if 0 <= y < out.shape[0] and 0 <= x < out.shape[1]:
                a = stencil[i, j, 3]
                out[y, x] = (
                    a * stencil[i, j, :3] +
                    (1 - a) * out[y, x]
                )

    return (out * 255).astype(np.uint8)

# %%
result = overlay_stencil(ball2, ball_stencil, 400, 200)

plt.figure(figsize=(6,4))
plt.imshow(result)
plt.axis("off")
plt.show()
