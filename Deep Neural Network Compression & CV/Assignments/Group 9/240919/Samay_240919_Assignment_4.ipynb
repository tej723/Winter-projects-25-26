# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTIONS 1 : Preps

# %% [markdown]
# ### Flat Image : reference as "flat"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Edge Image : reference as "edge"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Corner Image : reference as "corner"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c1 = """
...

"""

img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Multiple Coorners : reference as "corner2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c2 = """
...

"""

img_data_c2 = base64.b64decode(base64_image_c2)
corner2 = np.array(Image.open(io.BytesIO(img_data_c2)))

plt.imshow(corner2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(1121.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 1 : reference as "ball"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(625.5), np.float64(416.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 2 : reference as "ball2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball2 = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(642.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# ## SECTION 2 : Questions

# %% [markdown]
# ### Part A - Corner Detection
#
# Pick images of your choice which you feel should give a good output. Use above ones if you cannot find any else.
# Create or pick 3 images : one flat, one edge, one corner image. Examples shown above, you are free to you them too.
# Use the sobel kernels to find Ix and Iy ( or Gx and Gy whatever you call it ) and plot them. Then, create a scatter plot for Iy vs Ix. If you threshold, mention clearly that you have along with the threshold value too. Ideally make a function that takes the image and prints the graphs, also make the function return the Iy and Ix values for further questions.
# Hint: use grayscale only.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

gray_flat = cv2.cvtColor(flat, cv2.COLOR_RGB2GRAY)
gray_edge = cv2.cvtColor(edge, cv2.COLOR_RGB2GRAY)
gray_corner = cv2.cvtColor(corner, cv2.COLOR_RGB2GRAY)

sobel_x = np.array([[-1, 0, 1],
                    [-2, 0, 2],
                    [-1, 0, 1]])

sobel_y = np.array([[-1, -2, -1],
                    [ 0,  0,  0],
                    [ 1,  2,  1]])

def analyze_gradients(image, title="Image"):
    Ix = cv2.filter2D(image.astype(float), -1, sobel_x)
    Iy = cv2.filter2D(image.astype(float), -1, sobel_y)

    plt.figure(figsize=(10, 8))

    plt.subplot(2, 2, 1)
    plt.imshow(image, cmap='gray')
    plt.title(f"{title} - Original")
    plt.axis('off')

    plt.subplot(2, 2, 2)
    plt.imshow(Ix, cmap='gray')
    plt.title("Ix (Sobel X)")
    plt.axis('off')

    plt.subplot(2, 2, 3)
    plt.imshow(Iy, cmap='gray')
    plt.title("Iy (Sobel Y)")
    plt.axis('off')

    plt.subplot(2, 2, 4)
    plt.scatter(Ix.flatten(), Iy.flatten(), alpha=0.3, s=1)
    plt.xlabel('Ix')
    plt.ylabel('Iy')
    plt.title('Scatter Plot: Iy vs Ix')
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    return Ix, Iy

# Call the function
Ix_f, Iy_f = analyze_gradients(gray_flat, "Flat Region")
Ix_e, Iy_e = analyze_gradients(gray_edge, "Edge Region")
Ix_c, Iy_c = analyze_gradients(gray_corner, "Corner Region")

# %% [markdown]
# ### Part B - Ellipse Fitting and R Maps for Corner Detection
#
# Now, use the above functions ( basically Ix and Iy ) and the formulas in the pre-session videos to find values of a,b and c ( the second moments ) and calculate the eigenvalues lambda1 and lambda2. Then use those to create an R map for the entire image. Display the R map. Do it for the 3 images of part A. So, you might want to create a function that takes the image, loops over the pixels with a window, fits the ellipse over the window, calculates the lambdas, and value of R, essentially finding R values for all the pixels and returning an R-map ( a 2d image with only one channel where the value of a pixel is the r-value of that pixel in the original grayscale image ). Now, display these R maps. Notice how the corners are clearly visible in white.

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
def corner_detection(image , k=0.04, threshold=0.01):
  Ix = cv2.filter2D(image.astype(float), -1, sobel_x)
  Iy = cv2.filter2D(image.astype(float), -1, sobel_y)
  Ixx = cv2.GaussianBlur(Ix*Ix, (5, 5), 0)
  Iyy = cv2.GaussianBlur(Iy*Iy, (5, 5), 0)
  Ixy = cv2.GaussianBlur(Ix*Iy, (5, 5), 0)

  det_M = (Ixx*Iyy) - (Ixy**2)
  trace_M = Ixx + Iyy
  tr = np.sqrt(np.maximum(0, (trace_M**2) - 4 * det_M))
  lambda_1 = (trace_M + tr) / 2
  lambda_2 = (trace_M - tr) / 2
  R = (lambda_1 * lambda_2) - k * (lambda_1 + lambda_2)**2
  R_norm = cv2.normalize(R, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
  corner_mask = R > threshold * R.max()
  result_img = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
  result_img[corner_mask] = [255, 0, 0]

  plt.figure(figsize=(10, 5))

  plt.subplot(1, 2, 1)
  plt.imshow(R_norm, cmap='jet')
  plt.title("Corner Response (R)")

  plt.subplot(1, 2, 2)
  plt.imshow(result_img)
  plt.title("Detected Corners")
  plt.show()

  return R

R_flat = corner_detection(gray_flat)
R_edge = corner_detection(gray_edge)
R_corner = corner_detection(gray_corner)

# %% [markdown]
# ### Part C - Hough Transforms
#
# Again, import an image, create a function that takes the image, finds the canny edge map, then loops through it to find the equivalent line of each pixel, checks whether the slope and intercept are within acceptable limits of the accumulator size ( if not, discard ), does the voting procedure and creates the accumulator. Now, choose an accurate threshold for the accumulator to get the slope and intercept for a good number of lines in the image. One thing you can do is normalise the accumulator and use a 90 percent threshold ( just an example, im not telling if 90p is a good one or not ), then, mark the lines in the image using cv2 and display the final output. For the slope and intercept, choose the limit as per your image to get a good output. Please dont make it super large so it take hours to run and give the output.
#
# Now, you can do the same but with rho theta method. Do this in a separate code cell from slope-intercept method and notice how fast this is

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img_path = 'triangle.png'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
edges = cv2.Canny(gray_img, 50, 150)
height, width = edges.shape

m_min, m_max, m_step = -5.0, 5.0, 0.05
c_min, c_max, c_step = -width, height + width, 1
m_values = np.arange(m_min, m_max, m_step)
c_values = np.arange(c_min, c_max, c_step)

accumulator = np.zeros((len(c_values), len(m_values)), dtype=np.uint32)
edge_pixels = np.argwhere(edges > 0)

for y, x in edge_pixels:
    for m_idx, m in enumerate(m_values):
        c = y - m * x
        if c_min <= c < c_max:
            c_idx = int((c - c_min) / c_step)
            accumulator[c_idx, m_idx] += 1

acc_max = np.max(accumulator)
normalized_acc = accumulator / acc_max
threshold = 0.235
line_indices = np.argwhere(normalized_acc > threshold)
output_img = img.copy()

for c_idx, m_idx in line_indices:
    m = m_values[m_idx]
    c = c_values[c_idx]
    x1, x2 = 0, width
    y1, y2 = int(m * x1 + c), int(m * x2 + c)

    cv2.line(output_img, (x1, y1), (x2, y2), (0, 0, 255), 2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edges')

plt.subplot(1, 3, 2)
plt.imshow(normalized_acc, extent=[m_min, m_max, c_max, c_min], aspect='auto')
plt.title('Accumulator Space')
plt.xlabel('m')
plt.ylabel('c')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
plt.title('Detected Lines')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('triangle.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
edges = cv2.Canny(blurred, 50, 150)

height, width = edges.shape
thetas = np.deg2rad(np.arange(-90, 90))
diag_len = int(np.sqrt(width**2 + height**2))
rhos = np.linspace(-diag_len, diag_len, diag_len * 2)
accumulator = np.zeros((len(rhos), len(thetas)), dtype=np.uint32)
edge_pixels = np.argwhere(edges > 0)
cos_t = np.cos(thetas)
sin_t = np.sin(thetas)

for y, x in edge_pixels:
    for t_idx in range(len(thetas)):
        rho = x * cos_t[t_idx] + y * sin_t[t_idx]
        rho_idx = int(rho + diag_len)
        accumulator[rho_idx, t_idx] += 1
max_vote = np.max(accumulator)
threshold = 0.5 * max_vote
line_indices = np.argwhere(accumulator > threshold)
output_img = img.copy()

for rho_idx, theta_idx in line_indices:
    rho = rhos[rho_idx]
    theta = thetas[theta_idx]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho

    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))

    cv2.line(output_img, (x1, y1), (x2, y2), (0, 0, 255), 2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edges')

plt.subplot(1, 3, 2)
plt.imshow(accumulator, extent=[-90, 90, diag_len, -diag_len], aspect='auto')
plt.title('Rho-Theta Accumulator')
plt.xlabel('Theta')
plt.ylabel('Rho')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
plt.title('Detected Lines')
plt.show()

# %% [markdown]
# ### Bonus - Part D
#
# Here, what you have to do is something like :
# 1. Create a python function that will take the first image and a set of coordinates ( x1,y1 ) - top left and ( x2,y2 ) - bottom right to form a box around the white ball. Now, find gradients, select the biggest completed gradient ( maximum area contour ) and then create an RGBA ( 4 channel ) stencil.
#
# 2. Now, create another function that takes this stencil and second image and a coordinate ( x3,y3 ). Now, treat ( x3,y3 ) as center point and overlap the RGBA stencil with second image. Keep x3 y3 such that it is towards the right to make it look like that white ball is on the green pool image.
#
#
# Again, I do not expect you guys to get a really good result. Try your best though.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def ball_stencil(image, top_left, bottom_right):
    x1, y1 = top_left
    x2, y2 = bottom_right
    roi = image[y1:y2, x1:x2].copy()
    h, w = roi.shape[:2]
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    gx = cv2.Sobel(gray_roi, cv2.CV_64F, 1, 0, ksize=3)
    gy = cv2.Sobel(gray_roi, cv2.CV_64F, 0, 1, ksize=3)
    mag = np.sqrt(gx**2 + gy**2)
    dirct = np.arctan2(gy, gx)

    min_r, max_r = 10, min(h, w) // 2
    acc = np.zeros((h, w, max_r), dtype=np.uint32)

    edge_pixels = np.argwhere(mag > (0.2 * np.max(mag)))

    for y, x in edge_pixels:
        phi = dirct[y, x]
        for r in range(min_r, max_r):
            a = int(x - r * np.cos(phi))
            b = int(y - r * np.sin(phi))

            if 0 <= a < w and 0 <= b < h:
                acc[b, a, r] += 1
    b_center, a_center, r_final = np.unravel_index(np.argmax(acc), acc.shape)
    alpha_channel = np.zeros((h, w), dtype=np.uint8)
    cv2.circle(alpha_channel, (a_center, b_center), r_final, 255, -1)
    b_ch, g_ch, r_ch = cv2.split(roi)
    rgba_stencil = cv2.merge([r_ch, g_ch, b_ch, alpha_channel])

    return rgba_stencil, (a_center, b_center, r_final)


x1, y1 = 25, 25
x2, y2 = 350, 350
stencil, params = ball_stencil(ball, (x1, y1), (x2, y2))

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
roi_rgb = cv2.cvtColor(img[y1:y2, x1:x2], cv2.COLOR_BGR2RGB)
plt.imshow(ball)
plt.title("Original ROI Box")

plt.subplot(1, 2, 2)
plt.imshow(stencil)
plt.title("RGBA Stencil")

plt.tight_layout()
plt.show()

# %%
ball2
