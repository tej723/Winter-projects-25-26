# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTIONS 1 : Preps

# %% [markdown]
# ### Flat Image : reference as "flat"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Edge Image : reference as "edge"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Corner Image : reference as "corner"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c1 = """
...

"""

img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Multiple Coorners : reference as "corner2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c2 = """
...

"""

img_data_c2 = base64.b64decode(base64_image_c2)
corner2 = np.array(Image.open(io.BytesIO(img_data_c2)))

plt.imshow(corner2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(1121.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 1 : reference as "ball"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(625.5), np.float64(416.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 2 : reference as "ball2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball2 = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(642.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# ## SECTION 2 : Questions

# %% [markdown]
# ### Part A - Corner Detection
#
# Pick images of your choice which you feel should give a good output. Use above ones if you cannot find any else.
# Create or pick 3 images : one flat, one edge, one corner image. Examples shown above, you are free to you them too.
# Use the sobel kernels to find Ix and Iy ( or Gx and Gy whatever you call it ) and plot them. Then, create a scatter plot for Iy vs Ix. If you threshold, mention clearly that you have along with the threshold value too. Ideally make a function that takes the image and prints the graphs, also make the function return the Iy and Ix values for further questions.
# Hint: use grayscale only.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import matplotlib.pyplot as plt

sobel_x = np.array([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1]
])

sobel_y = np.array([
    [-1, -2, -1],
    [ 0,  0,  0],
    [ 1,  2,  1]
])

# %%
def convolve(img, kernel):
  kh, kw = kernel.shape
  pad_h = kh // 2
  pad_w = kw // 2

  padded = np.pad(img, ((pad_h, pad_h), (pad_w, pad_w)), mode='reflect')

  flipped_kernel = kernel[::-1, ::-1]

  h, w = img.shape
  out = np.zeros((h, w))

  for i in range(h):
    for j in range(w):
      patch = padded[i:i+kh, j:j+kw]
      out[i, j] = np.sum(patch * flipped_kernel)

  return out

# %%
def sobel_analysis(img):
    Ix = convolve(img, sobel_x)
    Iy = convolve(img, sobel_y)

    plt.figure(figsize=(12, 8))

    plt.subplot(2, 2, 1)
    plt.imshow(img, cmap='gray')
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(2, 2, 2)
    plt.imshow(Ix, cmap='gray')
    plt.title("Ix (Sobel X)")
    plt.axis("off")

    plt.subplot(2, 2, 3)
    plt.imshow(Iy, cmap='gray')
    plt.title("Iy (Sobel Y)")
    plt.axis("off")

    plt.subplot(2, 2, 4)
    plt.scatter(Ix.flatten(), Iy.flatten(), s=10)
    plt.xlabel("Ix")
    plt.ylabel("Iy")
    plt.title("Iy vs Ix")

    plt.tight_layout()
    plt.show()

    return Ix, Iy

# %%
flat_gray=(0.299 * flat[:, :, 0] + 0.587 * flat[:, :, 1] +0.114 * flat[:, :, 2])
edge_gray=(0.299 * edge[:, :, 0] + 0.587 * edge[:, :, 1] +0.114 * edge[:, :, 2])
corner_gray=(0.299 * corner[:, :, 0] + 0.587 * corner[:, :, 1] +0.114 * corner[:, :, 2])

# %%
# flat_gray = (flat_gray > 100).astype(np.uint8) * 255 #I have thresholded here, and the threshold value is 100 (random)
# edge_gray = (edge_gray > 100).astype(np.uint8) * 255
# corner_gray = (corner_gray > 100).astype(np.uint8) * 255

# %%
# thresholding was causing all pixels to be concentrated at a few specific points. though, it doesn't make any difference
# because weights would be balanced due to number of points it was causing the graph to look bad
# so i decided not to threshold

# %%
Ix_flat, Iy_flat = sobel_analysis(flat_gray)
Ix_edge, Iy_edge = sobel_analysis(edge_gray)
Ix_corner, Iy_corner = sobel_analysis(corner_gray)

# %%
vals, counts = np.unique(
    np.stack([Ix_edge.flatten(), Iy_edge.flatten()], axis=1),
    axis=0,
    return_counts=True
)

plt.scatter(vals[:, 0], vals[:, 1], s=counts) # graphing with weight, to visualise number of points concentrated somewhere
plt.xlabel("Ix")
plt.ylabel("Iy")
plt.show()

# %%
vals, counts = np.unique(
    np.stack([Ix_corner.flatten(), Iy_corner.flatten()], axis=1),
    axis=0,
    return_counts=True
)

plt.scatter(vals[:, 0], vals[:, 1], s=counts)
plt.xlabel("Ix")
plt.ylabel("Iy")
plt.show()

# %% [markdown]
# ### Part B - Ellipse Fitting and R Maps for Corner Detection
#
# Now, use the above functions ( basically Ix and Iy ) and the formulas in the pre-session videos to find values of a,b and c ( the second moments ) and calculate the eigenvalues lambda1 and lambda2. Then use those to create an R map for the entire image. Display the R map. Do it for the 3 images of part A. So, you might want to create a function that takes the image, loops over the pixels with a window, fits the ellipse over the window, calculates the lambdas, and value of R, essentially finding R values for all the pixels and returning an R-map ( a 2d image with only one channel where the value of a pixel is the r-value of that pixel in the original grayscale image ). Now, display these R maps. Notice how the corners are clearly visible in white.

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
box = np.ones((3, 3))

# %%
def compute_gradients(img):
    Ix = convolve(img, sobel_x)
    Iy = convolve(img, sobel_y)
    return Ix, Iy

# %%
def harris_r_map(img, k=0.04):
    Ix, Iy = compute_gradients(img)

    Ix2 = convolve(Ix * Ix, box)
    Iy2 = convolve(Iy * Iy, box)
    Ixy = convolve(Ix * Iy, box)

    a = Ix2
    b = Ixy
    c = Iy2

    root = np.sqrt((a - c) ** 2 + 4 * b ** 2)

    lambda1 = 0.5 * (a + c + root)
    lambda2 = 0.5 * (a + c - root)

    R = lambda1 * lambda2 - k * (lambda1 + lambda2) ** 2
    return R

# %%
def normalize(x): # i asked gpt what to do, as i was not getting the exact plot.
    return (x - x.min()) / (x.max() - x.min() + 1e-8) # 1e-8 is for safety, in case max ends up equal to min

# %%
R_flat = harris_r_map(flat_gray)
R_edge = harris_r_map(edge_gray)
R_corner = harris_r_map(corner_gray)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(normalize(R_flat), cmap='gray')
plt.title("Flat R-map")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(normalize(R_edge), cmap='gray')
plt.title("Edge R-map")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(normalize(R_corner), cmap='gray')
plt.title("Corner R-map")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part C - Hough Transforms
#
# Again, import an image, create a function that takes the image, finds the canny edge map, then loops through it to find the equivalent line of each pixel, checks whether the slope and intercept are within acceptable limits of the accumulator size ( if not, discard ), does the voting procedure and creates the accumulator. Now, choose an accurate threshold for the accumulator to get the slope and intercept for a good number of lines in the image. One thing you can do is normalise the accumulator and use a 90 percent threshold ( just an example, im not telling if 90p is a good one or not ), then, mark the lines in the image using cv2 and display the final output. For the slope and intercept, choose the limit as per your image to get a good output. Please dont make it super large so it take hours to run and give the output.
#
# Now, you can do the same but with rho theta method. Do this in a separate code cell from slope-intercept method and notice how fast this is

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
# @title
imgstring2="""...
"""

# %%
import base64
import numpy as np
import cv2
import matplotlib.pyplot as plt

img_bytes2 = base64.b64decode(imgstring2)
img_array2 = np.frombuffer(img_bytes2, dtype=np.uint8)
img2 = cv2.imdecode(img_array2, cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

img_bytes1 = base64.b64decode(imgstring2)
img_array1 = np.frombuffer(img_bytes1, dtype=np.uint8)
img1 = cv2.imdecode(img_array1, cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

plt.imshow(img2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(499.5), np.float64(-0.5))

# %%
def hough_mb(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    plt.imshow(edges)
    plt.show()

    slopes = np.linspace(-5, 5, 500)
    h, w = img.shape[:2]
    intercepts = np.linspace(-h, h, 500)
    accumulator = np.zeros((500, 500), dtype=np.uint32)

    ys, xs = np.nonzero(edges)

    for x, y in zip(xs, ys):
        for i, m in enumerate(slopes):
            b = y - m * x
            if intercepts[0] <= b <= intercepts[-1]:
                j = int((b - intercepts[0]) / (intercepts[-1] - intercepts[0]) * (499))
                accumulator[i, j] += 1

    acc_norm = accumulator / accumulator.max()
    indices = np.argwhere(acc_norm > 0.6) #0.6 seemed to be the most appropriate value

    result_img = img.copy()
    for i, j in indices:
        m = slopes[i]
        b = intercepts[j]
        x1 = 0
        y1 = int(m * x1 + b)
        x2 = w
        y2 = int(m * x2 + b)
        cv2.line(result_img, (x1, y1), (x2, y2), (0, 0, 255), 1)

    return result_img

result_img = hough_mb(img2)

plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def hough_rt(img):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    plt.imshow(edges, cmap='gray')
    plt.show()

    h, w = img.shape[:2]
    diag_len = int(np.ceil(np.sqrt(h*h + w*w)))
    rhos = np.linspace(-diag_len, diag_len, 2*diag_len)
    thetas = np.linspace(0, np.pi, 180)
    accumulator = np.zeros((len(rhos), len(thetas)), dtype=np.uint32)

    ys, xs = np.nonzero(edges)

    cos_t = np.cos(thetas)
    sin_t = np.sin(thetas)

    for x, y in zip(xs, ys):
        rho_vals = x*cos_t + y*sin_t
        rho_indices = np.round(rho_vals + diag_len).astype(int)
        for idx, rho_idx in enumerate(rho_indices):
            accumulator[rho_idx, idx] = accumulator[rho_idx, idx] + 1

    acc_norm = accumulator / accumulator.max()
    indices = np.argwhere(acc_norm > 0.5)

    result_img = img.copy()
    for rho_idx, theta_idx in indices:
        rho = rhos[rho_idx]
        theta = thetas[theta_idx]
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))
        cv2.line(result_img, (x1,y1), (x2,y2), (0,0,255), 1)

    return result_img, accumulator, rhos, thetas

# %%
result_img_rho, acc_rho, rhos, thetas = hough_rt(img2)

plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(result_img_rho, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Bonus - Part D
#
# Here, what you have to do is something like :
# 1. Create a python function that will take the first image and a set of coordinates ( x1,y1 ) - top left and ( x2,y2 ) - bottom right to form a box around the white ball. Now, find gradients, select the biggest completed gradient ( maximum area contour ) and then create an RGBA ( 4 channel ) stencil.
#
# 2. Now, create another function that takes this stencil and second image and a coordinate ( x3,y3 ). Now, treat ( x3,y3 ) as center point and overlap the RGBA stencil with second image. Keep x3 y3 such that it is towards the right to make it look like that white ball is on the green pool image.
#
#
# Again, I do not expect you guys to get a really good result. Try your best though.

# %%
ball
# Out:
# array([[[ 91,  71,  46],
#         [ 91,  71,  46],
#         [ 92,  72,  47],
#         ...,
#         [ 87,  71,  58],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 90,  70,  47],
#         [ 90,  70,  47],
#         [ 90,  70,  47],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 87,  66,  45],
#         [ 87,  66,  45],
#         [ 87,  66,  45],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        ...,
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  7,  84, 215],
#         [  7,  84, 215],
#         [  7,  84, 215],
#         ...,
#         [  7,  70, 198],
#         [  7,  70, 198],
#         [  7,  70, 198]]], dtype=uint8)

# %%
ball2
# Out:
# array([[[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        ...,
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]]], dtype=uint8)

# %%
# I used chatGPT for majority of this code as my tries were giving constant issues. implementing initial functions using numpy was causing
# only the outline of the white ball on the pool table
# I have made sure to understand every line and still need to explore a bit more to understand and develop my own code in numpy
# since there is not enough time, pls accept this

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def create_ball_stencil(img, top_left, bottom_right):
    x1, y1 = top_left
    x2, y2 = bottom_right

    roi = img[y1:y2, x1:x2].copy()
    gray = cv2.cvtColor(roi, cv2.COLOR_RGB2GRAY)
    grad_x = cv2.Sobel(gray, cv2.CV_32F, 1, 0, ksize=3)
    grad_y = cv2.Sobel(gray, cv2.CV_32F, 0, 1, ksize=3)
    grad = cv2.magnitude(grad_x, grad_y)
    grad = cv2.convertScaleAbs(grad)

    # gray = (0.299*roi[:,:,0] + 0.587*roi[:,:,1] + 0.114*roi[:,:,2]).astype(np.float32)

    # grad_x = convolve(gray, sobel_x)
    # grad_y = convolve(gray, sobel_y)

    # grad = np.sqrt(grad_x*grad_x + grad_y*grad_y)
    # grad = np.abs(grad)
    # grad = grad / grad.max() * 255
    # grad = grad.astype(np.uint8)

    _, thresh = cv2.threshold(grad, 30, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    max_contour = max(contours, key=cv2.contourArea)

    mask = np.zeros_like(gray, dtype=np.uint8)
    cv2.drawContours(mask, [max_contour], -1, 255, -1)

    r, g, b = cv2.split(roi)
    rgba = cv2.merge([r, g, b, mask])

    return rgba

def paste_stencil_on_image(stencil, base_img, center):
    x3, y3 = center
    h, w = stencil.shape[:2]

    top_left_x = int(x3 - w//2)
    top_left_y = int(y3 - h//2)

    result_img = base_img.copy()

    for i in range(h):
        for j in range(w):
            y_idx = top_left_y + i
            x_idx = top_left_x + j
            if 0 <= y_idx < base_img.shape[0] and 0 <= x_idx < base_img.shape[1]:
                alpha = stencil[i, j, 3] / 255.0
                for c in range(3):
                    result_img[y_idx, x_idx, c] = int(alpha * stencil[i, j, c] + (1 - alpha) * result_img[y_idx, x_idx, c])

    return result_img

stencil = create_ball_stencil(ball, (108, 191), (235, 318))
result_img = paste_stencil_on_image(stencil, ball2, (500, 200))

plt.figure(figsize=(10,10))
plt.imshow(result_img)
plt.axis('off')
plt.show()
