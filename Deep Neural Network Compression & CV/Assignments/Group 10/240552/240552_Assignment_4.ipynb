# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTIONS 1 : Preps

# %% [markdown]
# ### Flat Image : reference as "flat"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Edge Image : reference as "edge"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Corner Image : reference as "corner"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c1 = """
...

"""

img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Multiple Coorners : reference as "corner2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c2 = """
...

"""

img_data_c2 = base64.b64decode(base64_image_c2)
corner2 = np.array(Image.open(io.BytesIO(img_data_c2)))

plt.imshow(corner2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(1121.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 1 : reference as "ball"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[5], line 15
#       9 base64_image = """
#      10 [...
#      11
#      12 """
#      14 img_data = base64.b64decode(base64_image)
# ---> 15 ball = np.array(Image.open(io.BytesIO(img_data)))
#      17 plt.imshow(ball)
#      18 plt.axis("off")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3498, in open(fp, mode, formats)
#    3496     warnings.warn(message)
#    3497 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3498 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000002089F83C860>

# %% [markdown]
# ### Bonus Question Image 2 : reference as "ball2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball2 = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(642.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# ## SECTION 2 : Questions

# %% [markdown]
# ### Part A - Corner Detection
#
# Pick images of your choice which you feel should give a good output. Use above ones if you cannot find any else.
# Create or pick 3 images : one flat, one edge, one corner image. Examples shown above, you are free to you them too.
# Use the sobel kernels to find Ix and Iy ( or Gx and Gy whatever you call it ) and plot them. Then, create a scatter plot for Iy vs Ix. If you threshold, mention clearly that you have along with the threshold value too. Ideally make a function that takes the image and prints the graphs, also make the function return the Iy and Ix values for further questions.
# Hint: use grayscale only.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
def convolve(img_gray, kernel): # gray here means  2D array not of more dimensions
    k_r, k_c = kernel.shape
    pad_r = k_r // 2
    pad_c = k_c // 2
    padded = np.pad(img_gray, ((pad_r, pad_r), (pad_c, pad_c)), mode='reflect')
    h,b = img_gray.shape
    output = np.zeros((h, b))
    for i in range(h):
        for j in range(b):
            region = padded[i:i+k_r, j:j+k_c]
            output[i, j] = np.sum(region * kernel)
    return output

# %%
sobel_x = np.array([
    [-1,  0,  1],
    [-2,  0,  2],
    [-1,  0,  1]
])

sobel_y = np.array([
    [-1, -2, -1],
    [ 0,  0,  0],
    [ 1,  2,  1]
])

# %%
import cv2
img_rgb_1=np.array(corner)
img_gray_1=cv2.cvtColor(img_rgb_1,cv2.COLOR_RGB2GRAY)
img_rgb_2=np.array(corner2)
img_gray_2=cv2.cvtColor(img_rgb_2,cv2.COLOR_RGB2GRAY)
img_rgb_3=np.array(flat)
img_gray_3=cv2.cvtColor(img_rgb_3,cv2.COLOR_RGB2GRAY)
def scatter_plot(img_gray):
    Gx = convolve(img_gray, sobel_x)
    Gy = convolve(img_gray, sobel_y)
    return Gx,Gy
G_x_1,G_y_1=scatter_plot(img_gray_1)
G_x_2,G_y_2=scatter_plot(img_gray_2)
G_x_3,G_y_3=scatter_plot(img_gray_3)
gradient_magnitude = np.sqrt((G_x_1)**2 + (G_y_1)**2)
gradient_norm=gradient_magnitude/gradient_magnitude.max()
mag=(gradient_norm*255).astype(np.uint8)
T=(5*gradient_magnitude.max())/100
mask=mag>T
plt.figure(figsize=(24,24))
plt.subplot(2,2,1)
plt.scatter(G_x_1,G_y_1,s=3,alpha=0.5)
plt.xlabel("G_x_1")
plt.ylabel("G_y_1")
plt.title("scatter graph of corner")
plt.subplot(2,2,2)
plt.scatter(G_x_1[mask],G_y_1[mask],s=4,alpha=0.6)
plt.title("scattered graph of corner after threshold")
plt.xlabel("G_x_1")
plt.ylabel("G_y_1")
plt.subplot(2,2,3)
plt.scatter(G_x_2,G_y_2,s=3,alpha=0.5)
plt.xlabel("G_x_2")
plt.ylabel("G_y_2")
plt.title("scatter graph of corner2")
plt.subplot(2,2,4)
plt.scatter(G_x_3,G_y_3,s=3,alpha=0.5)
plt.xlabel("G_x_3")
plt.ylabel("G_y_3")
plt.title("scatter graph of flat")
plt.show()

# %% [markdown]
# ### Part B - Ellipse Fitting and R Maps for Corner Detection
#
# Now, use the above functions ( basically Ix and Iy ) and the formulas in the pre-session videos to find values of a,b and c ( the second moments ) and calculate the eigenvalues lambda1 and lambda2. Then use those to create an R map for the entire image. Display the R map. Do it for the 3 images of part A. So, you might want to create a function that takes the image, loops over the pixels with a window, fits the ellipse over the window, calculates the lambdas, and value of R, essentially finding R values for all the pixels and returning an R-map ( a 2d image with only one channel where the value of a pixel is the r-value of that pixel in the original grayscale image ). Now, display these R maps. Notice how the corners are clearly visible in white.

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
def corner_detection(img_gray, window_size=7, k=0.04):
    img_gray = img_gray.astype(np.float32)
    h, w = img_gray.shape
    R_map = np.zeros((h, w), dtype=np.float32)
    p = window_size // 2
    G_x = convolve(img_gray, sobel_x)
    G_y = convolve(img_gray, sobel_y)
    for y in range(p, h -p):
        for x in range(p, w -p):
            a = 0.0
            b = 0.0
            c = 0.0
            for j in range(-p, p + 1):
                for i in range(-p, p + 1):
                    ix = G_x[y + j, x + i]
                    iy = G_y[y + j, x + i]

                    a += ix * ix
                    b += ix * iy
                    c += iy * iy

            trace = a + c
            det = a * c - b * b
            temp = (a - c) ** 2 + 4 * b * b
            sqrt_term = np.sqrt(temp)

            lambda1 = (trace + sqrt_term) / 2.0
            lambda2 = (trace - sqrt_term) / 2.0

            R = lambda1 * lambda2 - k * (lambda1 + lambda2) ** 2
            R_map[y, x] = R

    return R_map
img_corner_1=corner_detection(img_gray_1)
img_corner_2=corner_detection(img_gray_2)
img_corner_3=corner_detection(img_gray_3)
plt.figure(figsize=(24,24))
plt.subplot(2,2,1)
plt.imshow(img_corner_1,cmap='gray')
plt.axis("off")
plt.subplot(2,2,2)
final_2=img_corner_2.copy()
final_2=final_2-final_2.min()
T_2=0.03*final_2.max()
final_2[final_2<T_2]=0
final_2 = final_2 / final_2.max()
plt.imshow(final_2,cmap='gray',vmin=0,vmax=1)
plt.axis("off")
plt.subplot(2,2,3)
plt.imshow(img_corner_3,cmap='gray')
plt.axis("off")

plt.show()

# %% [markdown]
# ### Part C - Hough Transforms
#
# Again, import an image, create a function that takes the image, finds the canny edge map, then loops through it to find the equivalent line of each pixel, checks whether the slope and intercept are within acceptable limits of the accumulator size ( if not, discard ), does the voting procedure and creates the accumulator. Now, choose an accurate threshold for the accumulator to get the slope and intercept for a good number of lines in the image. One thing you can do is normalise the accumulator and use a 90 percent threshold ( just an example, im not telling if 90p is a good one or not ), then, mark the lines in the image using cv2 and display the final output. For the slope and intercept, choose the limit as per your image to get a good output. Please dont make it super large so it take hours to run and give the output.
#
# Now, you can do the same but with rho theta method. Do this in a separate code cell from slope-intercept method and notice how fast this is

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
def hough_slope_intercept(
    img_gray,
    m_min=-10, m_max=10, m_step=0.02,
    b_min=-500, b_max=500, b_step=2,
    canny_low=100, canny_high=200
):
    edges = cv2.Canny(img_gray, canny_low, canny_high)

    height, width = edges.shape
    m_values = np.arange(m_min, m_max, m_step)
    b_values = np.arange(b_min, b_max, b_step)

    accumulator = np.zeros((len(m_values), len(b_values)), dtype=np.int32)
    for y in range(height):
        for x in range(width):
            if edges[y, x] != 0:
                for mi, m in enumerate(m_values):
                    b = y - m * x
                    if b_min <= b < b_max:
                        bi = int((b - b_min) / b_step)
                        accumulator[mi, bi] += 1
    return accumulator,m_values,b_values

# %%
def draw_lines_1(img_rgb, accumulator, m_vals, b_vals, threshold_ratio=0.5):
    output = img_rgb.copy()
    threshold = threshold_ratio * accumulator.max()

    ys, xs = np.where(accumulator > threshold)

    for i, j in zip(ys, xs):
        m = m_vals[i]
        b = b_vals[j]

        x1, x2 = 0, img_rgb.shape[1]
        y1 = int(m * x1 + b)
        y2 = int(m * x2 + b)

        cv2.line(output, (x1, y1), (x2, y2), (0, 0, 255), 2)

    return output

# %%
acc,m_values,b_values= hough_slope_intercept(
    img_gray_2,
    m_min=-100, m_max=100,
    b_min=-300, b_max=300
)

output_mb = draw_lines_1(img_rgb_2,acc,m_values,b_values)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Edges")
plt.imshow(edges, cmap='gray')
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Slope–Intercept Hough")
plt.imshow(output_mb)
plt.axis("off")
plt.show()

# %%
def hough_rho_theta(
    img_gray,
    rho_step=1,
    theta_step=180,
    canny_low=100,
    canny_high=200
):
    edges = cv2.Canny(img_gray, canny_low, canny_high)

    height, width = edges.shape
    diag_len = int(np.sqrt(height**2 + width**2))

    rhos = np.linspace(-diag_len, diag_len, 2*diag_len)
    thetas = np.deg2rad(np.linspace(-90, 90, theta_step))

    accumulator = np.zeros((len(rhos), len(thetas)), dtype=np.uint64)
    for y in range(height):
        for x in range(width):
            if edges[y, x] != 0:
                for ti, theta in enumerate(thetas):
                    rho = x * np.cos(theta) + y * np.sin(theta)
                    ri = int((rho + diag_len) / rho_step)
                    accumulator[ri, ti] += 1
    return accumulator,rhos,thetas

# %%
def draw_lines_2(img_rgb,accumulator, rhos,thetas,threshold_ratio=0.5):
    result = img_rgb.copy()
    threshold=threshold_ratio*accumulator.max()
    l,b=np.where(accumulator>threshold)

    for r_indx, t_indx in zip(l,b):
        Rho=rhos[r_indx]
        Theta=thetas[t_indx]
        a = np.cos(Theta)
        b = np.sin(Theta)

        x0 = a * Rho
        y0 = b * Rho

        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))

        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

    return result

# %%
accumulator,rhos,thetas= hough_rho_theta(
    img_gray_2
)

output_rt = draw_lines_2(img_rgb_2,accumulator,rhos,thetas)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Edges")
plt.imshow(edges_rt, cmap='gray')
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Rho–Theta Hough")
plt.imshow(output_rt)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Bonus - Part D
#
# Here, what you have to do is something like :
# 1. Create a python function that will take the first image and a set of coordinates ( x1,y1 ) - top left and ( x2,y2 ) - bottom right to form a box around the white ball. Now, find gradients, select the biggest completed gradient ( maximum area contour ) and then create an RGBA ( 4 channel ) stencil.
#
# 2. Now, create another function that takes this stencil and second image and a coordinate ( x3,y3 ). Now, treat ( x3,y3 ) as center point and overlap the RGBA stencil with second image. Keep x3 y3 such that it is towards the right to make it look like that white ball is on the green pool image.
#
#
# Again, I do not expect you guys to get a really good result. Try your best though.

# %%
ball
# Out:
# array([[[ 91,  71,  46],
#         [ 91,  71,  46],
#         [ 92,  72,  47],
#         ...,
#         [ 87,  71,  58],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 90,  70,  47],
#         [ 90,  70,  47],
#         [ 90,  70,  47],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 87,  66,  45],
#         [ 87,  66,  45],
#         [ 87,  66,  45],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        ...,
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  7,  84, 215],
#         [  7,  84, 215],
#         [  7,  84, 215],
#         ...,
#         [  7,  70, 198],
#         [  7,  70, 198],
#         [  7,  70, 198]]], dtype=uint8)

# %%
ball2
# Out:
# array([[[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        ...,
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]]], dtype=uint8)
